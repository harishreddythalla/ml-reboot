# %%
#Linear Regression from scratch implementation

# %%
import numpy as np
import matplotlib.pyplot as plt

#Generating synthetic data
np.random.seed(42)
X = np.linspace(0,10,50) #creating 50 evenly distributed data points between 0 and 10
y = 3*X+7+np.random.randn(50)*2

plt.scatter(X,y)
plt.title("Synthetic Data")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
#Initializing the parameters of our Linear Regression equation y= mx+b

m = 0.0 #slope
c = 0.0 #intercept
learning_rate = 0.01
epochs = 1000


#loss function
def mse_loss(y, y_pred):
    return np.mean((y-y_pred)**2)

n = len(X)
for epoch in range(epochs):
    y_pred = m*X+c
    mse = mse_loss(y, y_pred)
    dm = (-2/n)* np.sum(X*(y-y_pred))
    dc = (-2/n)* np.sum(y-y_pred)
    m -= learning_rate*dm
    c -= learning_rate*dc
    if epoch%100 ==0:
        print(f"Epoch {epoch}: m={m:.3f}, c={c:.3f}, loss={mse_loss(y, y_pred):.3f}")
# Out:
# Epoch 0: m=2.713, c=0.441, loss=563.452
# Epoch 100: m=3.545, c=3.288, loss=7.237
# Epoch 200: m=3.305, c=4.896, loss=4.520
# Epoch 300: m=3.160, c=5.865, loss=3.531
# Epoch 400: m=3.072, c=6.450, loss=3.171
# Epoch 500: m=3.019, c=6.803, loss=3.039
# Epoch 600: m=2.988, c=7.016, loss=2.992
# Epoch 700: m=2.968, c=7.145, loss=2.974
# Epoch 800: m=2.957, c=7.222, loss=2.968
# Epoch 900: m=2.950, c=7.269, loss=2.966

# %%
y_final = m*X+c
plt.scatter(X,y)
plt.plot(X, y_final, color = 'red')
plt.title('Fitted Line')
plt.show()
